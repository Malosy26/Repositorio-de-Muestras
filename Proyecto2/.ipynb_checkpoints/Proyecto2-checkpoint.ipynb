# %%
import pandas as pd

# %%
df=pd.read_csv('df_Clean_TripAdvisor 2023-09-05 14_24_13.csv')
df
# Out:
#       Unnamed: 0                              Nombre  Score  Excelente  \
# 0              0                           El Capote    3.5          8
# 1              1                            La Queda    4.5          8
# 2              2                      Limbo Tribunal    4.0         86
# 3              3  400 Grados Pizza - Maria de Molina    5.0         20
# 4              4                               Ginos    3.5         15
# ...          ...                                 ...    ...        ...
# 9407        9407                  Salutteria Luchana    4.0          0
# 9408        9408                 Cafetería Los Arcos    2.5          4
# 9409        9409          Restaurante Pipa Don Ramon    3.5          5
# 9410        9410                  El Rincon Murciano    4.0         29
# 9411        9411                         L'Abbraccio    4.0        132
#
#       MuyBueno  Normal  Malo  Pesimo  Num_Reviews  Posicion  ... America Sur  \
# ...
